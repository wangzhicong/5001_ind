# %%
from auto_ml import Predictor
#from auto_ml.utils import get_boston_dataset
import pandas as pd
import numpy as np

df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
#df_train['time']=df_train['time'].apply(lambda x: np.log(x))
del df_train['id']
del df_test['id']

column_descriptions = {
    'time': 'output',
    'penalty':'categorical'}

ml_predictor = Predictor(type_of_estimator='regressor',column_descriptions=column_descriptions)
#ml_predictor.train(data, model_names=['DeepLearningClassifier'])
ml_predictor.train(df_train, model_names=['DeepLearningRegressor'])

result = ml_predictor.predict(df_test)
# Out:
# Welcome to auto_ml! We're about to go through and make sense of your data using machine learning, and give you a production-ready pipeline to get predictions with.
#
# If you have any issues, or new feature ideas, let us know at http://auto.ml
# You are running on version 2.9.9
# Now using the model training_params that you passed in:
# {}
# After overwriting our defaults with your values, here are the final params that will be used to initialize the model:
# {'epochs': 1000, 'batch_size': 50, 'verbose': 2}
# Running basic data cleaning
# Performing feature scaling
# Fitting DataFrameVectorizer
# Now using the model training_params that you passed in:
# {}
# After overwriting our defaults with your values, here are the final params that will be used to initialize the model:
# {'epochs': 1000, 'batch_size': 50, 'verbose': 2}
#
#
# ********************************************************************************************
# About to fit the pipeline for the model DeepLearningRegressor to predict time
# Started at:
# 2018-10-27 15:58:22
#
# We will stop training early if we have not seen an improvement in validation accuracy in 25 epochs
# To measure validation accuracy, we will split off a random 10 percent of your training data set
# Train on 340 samples, validate on 60 samples
# Epoch 1/1000
#  - 1s - loss: 39.0416 - mean_absolute_error: 3.1695 - mean_absolute_percentage_error: 99.2843 - val_loss: 31.3308 - val_mean_absolute_error: 3.3496 - val_mean_absolute_percentage_error: 97.7493
# Epoch 2/1000
#  - 0s - loss: 38.9464 - mean_absolute_error: 3.1551 - mean_absolute_percentage_error: 97.0911 - val_loss: 31.1940 - val_mean_absolute_error: 3.3293 - val_mean_absolute_percentage_error: 93.9814
# Epoch 3/1000
#  - 0s - loss: 38.7420 - mean_absolute_error: 3.1227 - mean_absolute_percentage_error: 91.9503 - val_loss: 30.7732 - val_mean_absolute_error: 3.2663 - val_mean_absolute_percentage_error: 82.4818
# Epoch 4/1000
#  - 0s - loss: 37.8848 - mean_absolute_error: 2.9998 - mean_absolute_percentage_error: 78.6684 - val_loss: 28.7745 - val_mean_absolute_error: 3.0378 - val_mean_absolute_percentage_error: 87.5070
# Epoch 5/1000
#  - 0s - loss: 34.2341 - mean_absolute_error: 2.6494 - mean_absolute_percentage_error: 107.5265 - val_loss: 21.6708 - val_mean_absolute_error: 2.7351 - val_mean_absolute_percentage_error: 285.0734
# Epoch 6/1000
#  - 0s - loss: 28.7500 - mean_absolute_error: 2.8717 - mean_absolute_percentage_error: 338.4196 - val_loss: 19.3513 - val_mean_absolute_error: 2.7486 - val_mean_absolute_percentage_error: 360.2744
# Epoch 7/1000
#  - 0s - loss: 27.3674 - mean_absolute_error: 2.9016 - mean_absolute_percentage_error: 340.4242 - val_loss: 17.7438 - val_mean_absolute_error: 3.1050 - val_mean_absolute_percentage_error: 565.4373
# Epoch 8/1000
#  - 0s - loss: 25.9228 - mean_absolute_error: 3.1031 - mean_absolute_percentage_error: 401.3601 - val_loss: 15.6711 - val_mean_absolute_error: 2.5465 - val_mean_absolute_percentage_error: 366.4588
# Epoch 9/1000
#  - 0s - loss: 23.1347 - mean_absolute_error: 2.4808 - mean_absolute_percentage_error: 238.4196 - val_loss: 13.3236 - val_mean_absolute_error: 2.0942 - val_mean_absolute_percentage_error: 204.2164
# Epoch 10/1000
#  - 0s - loss: 19.6069 - mean_absolute_error: 2.3788 - mean_absolute_percentage_error: 210.1236 - val_loss: 11.5084 - val_mean_absolute_error: 2.0658 - val_mean_absolute_percentage_error: 219.6470
# Epoch 11/1000
#  - 0s - loss: 18.3129 - mean_absolute_error: 2.3997 - mean_absolute_percentage_error: 207.9900 - val_loss: 13.4505 - val_mean_absolute_error: 2.3081 - val_mean_absolute_percentage_error: 231.7936
# Epoch 12/1000
#  - 0s - loss: 18.2138 - mean_absolute_error: 2.2802 - mean_absolute_percentage_error: 204.3331 - val_loss: 11.5488 - val_mean_absolute_error: 2.4506 - val_mean_absolute_percentage_error: 250.8418
# Epoch 13/1000
#  - 0s - loss: 18.3670 - mean_absolute_error: 2.4510 - mean_absolute_percentage_error: 224.3785 - val_loss: 10.8365 - val_mean_absolute_error: 2.1523 - val_mean_absolute_percentage_error: 228.3183
# Epoch 14/1000
#  - 0s - loss: 17.3021 - mean_absolute_error: 2.4633 - mean_absolute_percentage_error: 210.8211 - val_loss: 13.1993 - val_mean_absolute_error: 2.6809 - val_mean_absolute_percentage_error: 274.6534
# Epoch 15/1000
#  - 0s - loss: 16.4544 - mean_absolute_error: 2.4356 - mean_absolute_percentage_error: 218.9103 - val_loss: 12.3189 - val_mean_absolute_error: 2.2566 - val_mean_absolute_percentage_error: 232.1706
# Epoch 16/1000
#  - 0s - loss: 17.4282 - mean_absolute_error: 2.4259 - mean_absolute_percentage_error: 209.2050 - val_loss: 10.5499 - val_mean_absolute_error: 2.2260 - val_mean_absolute_percentage_error: 230.7218
# Epoch 17/1000
#  - 0s - loss: 17.0931 - mean_absolute_error: 2.3717 - mean_absolute_percentage_error: 198.0946 - val_loss: 10.8556 - val_mean_absolute_error: 2.3269 - val_mean_absolute_percentage_error: 224.6015
# Epoch 18/1000
#  - 0s - loss: 17.5888 - mean_absolute_error: 2.5822 - mean_absolute_percentage_error: 217.5554 - val_loss: 13.7048 - val_mean_absolute_error: 2.6862 - val_mean_absolute_percentage_error: 252.3060
# Epoch 19/1000
#  - 0s - loss: 16.0620 - mean_absolute_error: 2.4126 - mean_absolute_percentage_error: 207.0260 - val_loss: 10.2288 - val_mean_absolute_error: 2.1519 - val_mean_absolute_percentage_error: 205.2980
# Epoch 20/1000
#  - 0s - loss: 15.2958 - mean_absolute_error: 2.2417 - mean_absolute_percentage_error: 183.7281 - val_loss: 19.9480 - val_mean_absolute_error: 3.3795 - val_mean_absolute_percentage_error: 285.9076
# Epoch 21/1000
#  - 0s - loss: 17.2973 - mean_absolute_error: 2.4859 - mean_absolute_percentage_error: 210.8291 - val_loss: 11.2563 - val_mean_absolute_error: 2.3502 - val_mean_absolute_percentage_error: 222.2700
# Epoch 22/1000
#  - 0s - loss: 15.3097 - mean_absolute_error: 2.2617 - mean_absolute_percentage_error: 185.9901 - val_loss: 21.2969 - val_mean_absolute_error: 3.4743 - val_mean_absolute_percentage_error: 289.7962
# Epoch 23/1000
#  - 0s - loss: 16.7562 - mean_absolute_error: 2.3701 - mean_absolute_percentage_error: 187.8792 - val_loss: 11.5047 - val_mean_absolute_error: 2.4033 - val_mean_absolute_percentage_error: 220.6426
# Epoch 24/1000
#  - 0s - loss: 14.7150 - mean_absolute_error: 2.1381 - mean_absolute_percentage_error: 168.6416 - val_loss: 15.5346 - val_mean_absolute_error: 2.8411 - val_mean_absolute_percentage_error: 244.1085
# Epoch 25/1000
#  - 0s - loss: 16.3756 - mean_absolute_error: 2.3156 - mean_absolute_percentage_error: 171.8295 - val_loss: 12.8061 - val_mean_absolute_error: 2.5471 - val_mean_absolute_percentage_error: 214.5317
# Epoch 26/1000
#  - 0s - loss: 15.4793 - mean_absolute_error: 2.1380 - mean_absolute_percentage_error: 148.8377 - val_loss: 14.8323 - val_mean_absolute_error: 2.7162 - val_mean_absolute_percentage_error: 229.5301
# Epoch 27/1000
#  - 0s - loss: 15.5873 - mean_absolute_error: 2.4201 - mean_absolute_percentage_error: 178.3141 - val_loss: 12.5748 - val_mean_absolute_error: 2.4961 - val_mean_absolute_percentage_error: 214.9444
# Epoch 28/1000
#  - 0s - loss: 14.3487 - mean_absolute_error: 2.3055 - mean_absolute_percentage_error: 173.5112 - val_loss: 12.0258 - val_mean_absolute_error: 2.4301 - val_mean_absolute_percentage_error: 201.1789
# Epoch 29/1000
#  - 0s - loss: 14.9406 - mean_absolute_error: 2.1701 - mean_absolute_percentage_error: 146.8403 - val_loss: 24.8557 - val_mean_absolute_error: 3.5988 - val_mean_absolute_percentage_error: 259.3678
# Epoch 30/1000
#  - 0s - loss: 16.2579 - mean_absolute_error: 2.4399 - mean_absolute_percentage_error: 160.4805 - val_loss: 12.6299 - val_mean_absolute_error: 2.4854 - val_mean_absolute_percentage_error: 184.6850
# Epoch 31/1000
#  - 0s - loss: 15.2686 - mean_absolute_error: 2.1484 - mean_absolute_percentage_error: 133.5946 - val_loss: 10.4205 - val_mean_absolute_error: 2.1563 - val_mean_absolute_percentage_error: 135.2633
# Epoch 32/1000
#  - 0s - loss: 14.8771 - mean_absolute_error: 2.1172 - mean_absolute_percentage_error: 129.8984 - val_loss: 10.1611 - val_mean_absolute_error: 2.1031 - val_mean_absolute_percentage_error: 120.6954
# Epoch 33/1000
#  - 0s - loss: 14.4101 - mean_absolute_error: 2.2011 - mean_absolute_percentage_error: 128.9834 - val_loss: 10.8861 - val_mean_absolute_error: 2.2566 - val_mean_absolute_percentage_error: 140.6612
# Epoch 34/1000
#  - 0s - loss: 14.7576 - mean_absolute_error: 2.1924 - mean_absolute_percentage_error: 124.5104 - val_loss: 10.4103 - val_mean_absolute_error: 2.1478 - val_mean_absolute_percentage_error: 118.7032
# Epoch 35/1000
#  - 0s - loss: 14.4822 - mean_absolute_error: 2.2008 - mean_absolute_percentage_error: 117.6454 - val_loss: 10.1677 - val_mean_absolute_error: 2.1144 - val_mean_absolute_percentage_error: 107.4000
# Epoch 36/1000
#  - 0s - loss: 13.3743 - mean_absolute_error: 1.9685 - mean_absolute_percentage_error: 96.2410 - val_loss: 16.1733 - val_mean_absolute_error: 2.6351 - val_mean_absolute_percentage_error: 143.2071
# Epoch 37/1000
#  - 0s - loss: 13.7692 - mean_absolute_error: 2.0531 - mean_absolute_percentage_error: 92.8839 - val_loss: 10.3571 - val_mean_absolute_error: 2.0822 - val_mean_absolute_percentage_error: 83.2502
# Epoch 38/1000
#  - 0s - loss: 13.3458 - mean_absolute_error: 1.9271 - mean_absolute_percentage_error: 79.1048 - val_loss: 10.9949 - val_mean_absolute_error: 2.1599 - val_mean_absolute_percentage_error: 86.1303
# Epoch 39/1000
#  - 0s - loss: 14.1852 - mean_absolute_error: 2.0083 - mean_absolute_percentage_error: 85.6591 - val_loss: 12.9894 - val_mean_absolute_error: 2.0460 - val_mean_absolute_percentage_error: 61.2455
# Epoch 40/1000
#  - 0s - loss: 14.8995 - mean_absolute_error: 1.9579 - mean_absolute_percentage_error: 71.6773 - val_loss: 14.5723 - val_mean_absolute_error: 2.4652 - val_mean_absolute_percentage_error: 111.4459
# Epoch 41/1000
#  - 0s - loss: 15.4421 - mean_absolute_error: 2.0790 - mean_absolute_percentage_error: 81.9642 - val_loss: 10.9464 - val_mean_absolute_error: 2.0964 - val_mean_absolute_percentage_error: 78.9629
# Epoch 42/1000
#  - 0s - loss: 13.0200 - mean_absolute_error: 1.8074 - mean_absolute_percentage_error: 72.6735 - val_loss: 11.1391 - val_mean_absolute_error: 2.1536 - val_mean_absolute_percentage_error: 87.2269
# Epoch 43/1000
#  - 0s - loss: 13.5598 - mean_absolute_error: 1.9554 - mean_absolute_percentage_error: 79.7917 - val_loss: 11.4709 - val_mean_absolute_error: 2.1895 - val_mean_absolute_percentage_error: 88.3859
# Epoch 44/1000
#  - 0s - loss: 14.0109 - mean_absolute_error: 1.8893 - mean_absolute_percentage_error: 73.9493 - val_loss: 10.4994 - val_mean_absolute_error: 1.9548 - val_mean_absolute_percentage_error: 84.6843
# Epoch 45/1000
#  - 0s - loss: 14.8872 - mean_absolute_error: 1.8999 - mean_absolute_percentage_error: 77.5855 - val_loss: 17.1039 - val_mean_absolute_error: 2.6424 - val_mean_absolute_percentage_error: 141.3022
# Epoch 46/1000
#  - 0s - loss: 12.5539 - mean_absolute_error: 1.8231 - mean_absolute_percentage_error: 88.0028 - val_loss: 13.7925 - val_mean_absolute_error: 2.4058 - val_mean_absolute_percentage_error: 131.7280
# Epoch 47/1000
#  - 0s - loss: 10.8685 - mean_absolute_error: 1.7178 - mean_absolute_percentage_error: 86.1230 - val_loss: 10.4060 - val_mean_absolute_error: 2.0131 - val_mean_absolute_percentage_error: 116.9842
# Epoch 48/1000
#  - 0s - loss: 14.0062 - mean_absolute_error: 1.9349 - mean_absolute_percentage_error: 98.7414 - val_loss: 10.5488 - val_mean_absolute_error: 1.9779 - val_mean_absolute_percentage_error: 121.1267
# Epoch 49/1000
#  - 0s - loss: 13.3368 - mean_absolute_error: 1.9110 - mean_absolute_percentage_error: 111.6571 - val_loss: 11.3834 - val_mean_absolute_error: 2.1574 - val_mean_absolute_percentage_error: 138.4534
# Epoch 50/1000
#  - 0s - loss: 13.5112 - mean_absolute_error: 1.8385 - mean_absolute_percentage_error: 101.1106 - val_loss: 16.6596 - val_mean_absolute_error: 2.6245 - val_mean_absolute_percentage_error: 164.5275
# Epoch 51/1000
#  - 0s - loss: 12.2175 - mean_absolute_error: 1.7880 - mean_absolute_percentage_error: 106.8744 - val_loss: 12.2249 - val_mean_absolute_error: 2.2039 - val_mean_absolute_percentage_error: 134.1666
# Epoch 52/1000
#  - 0s - loss: 14.0961 - mean_absolute_error: 1.8438 - mean_absolute_percentage_error: 101.6092 - val_loss: 11.2788 - val_mean_absolute_error: 2.0866 - val_mean_absolute_percentage_error: 128.9936
# Epoch 53/1000
#  - 0s - loss: 14.5894 - mean_absolute_error: 1.8913 - mean_absolute_percentage_error: 104.8966 - val_loss: 11.2234 - val_mean_absolute_error: 2.0408 - val_mean_absolute_percentage_error: 130.9716
# Epoch 54/1000
#  - 0s - loss: 12.4601 - mean_absolute_error: 1.8105 - mean_absolute_percentage_error: 104.7986 - val_loss: 13.8408 - val_mean_absolute_error: 2.4015 - val_mean_absolute_percentage_error: 149.2680
# Epoch 55/1000
#  - 0s - loss: 12.3937 - mean_absolute_error: 1.8536 - mean_absolute_percentage_error: 108.0230 - val_loss: 11.7285 - val_mean_absolute_error: 2.1081 - val_mean_absolute_percentage_error: 140.4571
# Epoch 56/1000
#  - 0s - loss: 12.1748 - mean_absolute_error: 1.8090 - mean_absolute_percentage_error: 113.9106 - val_loss: 14.3270 - val_mean_absolute_error: 2.4407 - val_mean_absolute_percentage_error: 166.2642
# Epoch 57/1000
#  - 0s - loss: 12.9187 - mean_absolute_error: 1.8422 - mean_absolute_percentage_error: 118.6004 - val_loss: 21.6736 - val_mean_absolute_error: 2.9706 - val_mean_absolute_percentage_error: 197.5583
# Epoch 00057: early stopping
# Finished training the pipeline!
# Total training time:
# 0:00:06
# Calculating feature responses, for advanced analytics.
# Here are our feature responses for the trained model
# +----+----------------------+----------+-------------------+-------------------+-----------+-----------+
# |    | Feature Name         |    Delta |   FR_Decrementing |   FR_Incrementing |   FRD_MAD |   FRI_MAD |
# |----+----------------------+----------+-------------------+-------------------+-----------+-----------|
# | 11 | l1_ratio             |   0.1598 |           -0.0123 |            0.0123 |    0.0065 |    0.0066 |
# | 10 | scale                |   0.1582 |           -0.0305 |            0.0308 |    0.0164 |    0.0174 |
# |  9 | alpha                |   0.2257 |            0.0373 |           -0.0365 |    0.0166 |    0.0154 |
# |  8 | n_informative        |   0.1440 |           -0.0386 |            0.0390 |    0.0196 |    0.0211 |
# |  7 | random_state         |   0.1528 |           -0.0510 |            0.0517 |    0.0263 |    0.0288 |
# |  6 | n_clusters_per_class |   0.1832 |            0.1295 |           -0.1243 |    0.0665 |    0.0518 |
# |  5 | flip_y               |   0.1647 |           -0.1698 |            0.1776 |    0.0752 |    0.1033 |
# |  4 | n_jobs               |   0.1638 |            0.2850 |           -0.2648 |    0.1772 |    0.1043 |
# |  3 | n_classes            |   0.1556 |           -0.3287 |            0.3596 |    0.1253 |    0.2409 |
# |  2 | n_features           |   0.1584 |           -0.3696 |            0.4089 |    0.1368 |    0.2867 |
# |  1 | n_samples            |   0.1579 |           -0.5937 |            0.7020 |    0.1850 |    0.6190 |
# |  0 | max_iter             |   0.1598 |           -0.5984 |            0.7083 |    0.1865 |    0.6256 |
# | 12 | penalty=l1           | nan      |          nan      |          nan      |  nan      |  nan      |
# | 13 | penalty=l2           | nan      |          nan      |          nan      |  nan      |  nan      |
# | 14 | penalty=elasticnet   | nan      |          nan      |          nan      |  nan      |  nan      |
# | 15 | penalty=none         | nan      |          nan      |          nan      |  nan      |  nan      |
# +----+----------------------+----------+-------------------+-------------------+-----------+-----------+

# %%
result = list(result)
result = [0 if x < 0 else x for x in result]
#result = [np.exp(result[i]) for i in range(len(result))]

index = list(range(0,len(result)))
output = {'id':index,'Time':result}
output = pd.DataFrame(output)
output = pd.DataFrame(output,columns=['id', 'Time'])

from sklearn.metrics import mean_squared_error as mse
baseline = pd.read_csv('baseline.csv')
baseline_label=list(baseline['Time'].values)
print(mse(np.array(result),baseline_label))

model='auto_ml'
output.to_csv(model+'.csv',index=False)
# Out:
# 10.141759808715834
